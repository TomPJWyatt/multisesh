# %%
import multisesh
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import multisesh
#
# File ~/dev/Python/multisesh/src/multisesh/__init__.py:1
# ----> 1 from .Classes import XFold,Session,TFile,TData,PlotDataFrame
#       2 from .OutDir import OutDir
#       3 from .exceptions import UnknownTifMeta
#
# File ~/dev/Python/multisesh/src/multisesh/Classes.py:27
#      23 import matplotlib.pyplot as plt
#      24 from matplotlib.colors import hsv_to_rgb
#      25 import ipywidgets as widgets
#      26 from IPython.display import display
# ---> 27 from basicpy import BaSiC
#      28 from aicsimageio import AICSImage
#      29 import btrack
#      30
#
# File /opt/miniconda3/envs/multisesh/lib/python3.11/site-packages/basicpy/__init__.py:7
#       4 import os
#       6 from basicpy import datasets
# ----> 7 from basicpy.basicpy import BaSiC
# ...
